# %% [markdown]
# Le prétraitement des données

# %%
import pandas as pd
import numpy as np
import os
import glob
from collections import defaultdict


FAMILLES_CIBLES = ['DDoS', 'DoS', 'Mirai', 'Recon', 'Spoofing', 'Injection']
LABEL_BENIN = 'BenignTraffic'
MAPPING_EXPLICITE = {
    'DNS_Spoofing': 'Spoofing', 'MITM-ArpSpoofing': 'Spoofing',
    'SqlInjection': 'Injection', 'CommandInjection': 'Injection',
    'XSS': 'Injection', 'Uploading_Attack': 'Injection'
}

def mapper_famille(label):
    if label == LABEL_BENIN: return LABEL_BENIN
    if label in MAPPING_EXPLICITE: return MAPPING_EXPLICITE[label]
    for famille in FAMILLES_CIBLES:
        if label.startswith(famille): return famille
    return None


DATASET_PATH = "../data/CICIoT2023"
CACHE_PATH = "../data/cache_filtre.csv"
fichiers = sorted(glob.glob(os.path.join(DATASET_PATH, "*.csv")))
compteur = defaultdict(int)
max_par_famille = 150000 
premiere_ecriture = True

for i, f in enumerate(fichiers, 1):
    for chunk in pd.read_csv(f, chunksize=50000):
        chunk['famille'] = chunk['label'].apply(mapper_famille)
        chunk = chunk[chunk['famille'].notna()]
        
        chunks_filtres = []
        for fam in chunk['famille'].unique():
            reste = max_par_famille - compteur[fam]
            if reste > 0:
                sous_chunk = chunk[chunk['famille'] == fam].head(reste)
                compteur[fam] += len(sous_chunk)
                chunks_filtres.append(sous_chunk)
        
        if chunks_filtres:
            chunk_final = pd.concat(chunks_filtres).drop(columns=['famille'])
            chunk_final.to_csv(CACHE_PATH, mode='a', header=premiere_ecriture, index=False)
            premiere_ecriture = False
    print(f"Processed file {i}/{len(fichiers)}")
# Out:
# Processed file 1/169
# Processed file 2/169
# Processed file 3/169
# Processed file 4/169
# Processed file 5/169
# Processed file 6/169
# Processed file 7/169
# Processed file 8/169
# Processed file 9/169
# Processed file 10/169
# Processed file 11/169
# Processed file 12/169
# Processed file 13/169
# Processed file 14/169
# Processed file 15/169
# Processed file 16/169
# Processed file 17/169
# Processed file 18/169
# Processed file 19/169
# Processed file 20/169
# Processed file 21/169
# Processed file 22/169
# Processed file 23/169
# Processed file 24/169
# Processed file 25/169
# Processed file 26/169
# Processed file 27/169
# Processed file 28/169
# Processed file 29/169
# Processed file 30/169
# Processed file 31/169
# Processed file 32/169
# Processed file 33/169
# Processed file 34/169
# Processed file 35/169
# Processed file 36/169
# Processed file 37/169
# Processed file 38/169
# Processed file 39/169
# Processed file 40/169
# Processed file 41/169
# Processed file 42/169
# Processed file 43/169
# Processed file 44/169
# Processed file 45/169
# Processed file 46/169
# Processed file 47/169
# Processed file 48/169
# Processed file 49/169
# Processed file 50/169
# Processed file 51/169
# Processed file 52/169
# Processed file 53/169
# Processed file 54/169
# Processed file 55/169
# Processed file 56/169
# Processed file 57/169
# Processed file 58/169
# Processed file 59/169
# Processed file 60/169
# Processed file 61/169
# Processed file 62/169
# Processed file 63/169
# Processed file 64/169
# Processed file 65/169
# Processed file 66/169
# Processed file 67/169
# Processed file 68/169
# Processed file 69/169
# Processed file 70/169
# Processed file 71/169
# Processed file 72/169
# Processed file 73/169
# Processed file 74/169
# Processed file 75/169
# Processed file 76/169
# Processed file 77/169
# Processed file 78/169
# Processed file 79/169
# Processed file 80/169
# Processed file 81/169
# Processed file 82/169
# Processed file 83/169
# Processed file 84/169
# Processed file 85/169
# Processed file 86/169
# Processed file 87/169
# Processed file 88/169
# Processed file 89/169
# Processed file 90/169
# Processed file 91/169
# Processed file 92/169
# Processed file 93/169
# Processed file 94/169
# Processed file 95/169
# Processed file 96/169
# Processed file 97/169
# Processed file 98/169
# Processed file 99/169
# Processed file 100/169
# Processed file 101/169
# Processed file 102/169
# Processed file 103/169
# Processed file 104/169
# Processed file 105/169
# Processed file 106/169
# Processed file 107/169
# Processed file 108/169
# Processed file 109/169
# Processed file 110/169
# Processed file 111/169
# Processed file 112/169
# Processed file 113/169
# Processed file 114/169
# Processed file 115/169
# Processed file 116/169
# Processed file 117/169
# Processed file 118/169
# Processed file 119/169
# Processed file 120/169
# Processed file 121/169
# Processed file 122/169
# Processed file 123/169
# Processed file 124/169
# Processed file 125/169
# Processed file 126/169
# Processed file 127/169
# Processed file 128/169
# Processed file 129/169
# Processed file 130/169
# Processed file 131/169
# Processed file 132/169
# Processed file 133/169
# Processed file 134/169
# Processed file 135/169
# Processed file 136/169
# Processed file 137/169
# Processed file 138/169
# Processed file 139/169
# Processed file 140/169
# Processed file 141/169
# Processed file 142/169
# Processed file 143/169
# Processed file 144/169
# Processed file 145/169
# Processed file 146/169
# Processed file 147/169
# Processed file 148/169
# Processed file 149/169
# Processed file 150/169
# Processed file 151/169
# Processed file 152/169
# Processed file 153/169
# Processed file 154/169
# Processed file 155/169
# Processed file 156/169
# Processed file 157/169
# Processed file 158/169
# Processed file 159/169
# Processed file 160/169
# Processed file 161/169
# Processed file 162/169
# Processed file 163/169
# Processed file 164/169
# Processed file 165/169
# Processed file 166/169
# Processed file 167/169
# Processed file 168/169
# Processed file 169/169
